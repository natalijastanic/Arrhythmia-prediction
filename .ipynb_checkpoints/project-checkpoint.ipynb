# %% [markdown]
# # Decision-making systems in medicine (Sistemi odlucivanja u medicini SOM 13E053SOM)
# ## Project prediction of Arrhythmia (data set from https://archive.ics.uci.edu/ml/datasets/Arrhythmia)

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1) Dataset analysis

# %%
data = pd.read_csv('01_arrhythmia_dataset.csv')
data.head(10)
# Out:
#    age  sex  height  weight  qrs_duration  p-r_interval  q-t_interval  \
# 0   75    0     190      80            91           193           371
# 1   56    1     165      64            81           174           401
# 2   54    0     172      95           138           163           386
# 3   55    0     175      94           100           202           380
# 4   75    0     190      80            88           181           360
# 5   13    0     169      51           100           167           321
# 6   40    1     160      52            77           129           377
# 7   49    1     162      54            78             0           376
# 8   44    0     168      56            84           118           354
# 9   50    1     167      67            89           130           383
#
#    t_interval  p_interval  qrs  ...   KY    KZ   LA   LB LC   LD   LE    LF  \
# 0         174         121  -16  ...  0.0   9.0 -0.9  0.0  0  0.9  2.9  23.3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Columns: 280 entries, age to diagnosis
# dtypes: float64(116), int64(159), object(5)
# memory usage: 988.9+ KB

# %%
# Quick check only for columns 10-14
print("\n" + "="*60)
print("QUICK CHECK: COLUMNS 10-14 (VECTOR ANGLES)")
print("="*60)

for col_idx in range(10, 15):
    col = data.iloc[:, col_idx]
    print(f"\nColumn {col_idx}:")
    print(f"  Type: {col.dtype}")
    
    if col.dtype == 'object':
        print(f"  Contains '?': {(col == '?').sum()}")
        print(f"  Sample values: {col.head(10).tolist()}")
    else:
        print(f"  Min: {col.min()}, Max: {col.max()}")
        print(f"  NaN count: {col.isna().sum()}")

print("="*60)
print("ANALYSIS OF INVALID VALUES")
print("="*60)
# Out:
# ...
# QUICK CHECK: COLUMNS 10-14 (VECTOR ANGLES)
# ...
#
# Column 10:
#   Type: object
#   Contains '?': 8
#   Sample values: ['13', '37', '34', '11', '13', '66', '49', '7', '69', '34']
#
# Column 11:
#   Type: object
#   Contains '?': 22
#   Sample values: ['64', '-17', '70', '-5', '61', '52', '75', '8', '78', '70']
#
# Column 12:
#   Type: object
#   Contains '?': 1
#   Sample values: ['-2', '31', '66', '20', '3', '88', '65', '51', '66', '71']
#
# Column 13:
#   Type: object
#   Contains '?': 376
#   Sample values: ['?', '?', '23', '?', '?', '?', '?', '?', '84', '?']
#
# Column 14:
#   Type: object
#   Contains '?': 1
#   Sample values: ['63', '53', '75', '71', '?', '84', '70', '67', '64', '63']
# ...
# ANALYSIS OF INVALID VALUES
# ...

# %% [markdown]
# ### Problem Analysis
#
# - **Column 10 (index 10):** 8 `'?'` values – *small*, fill with median
# - **Column 11 (index 11):** 22 `'?'` values – *small*, fill with median
# - **Column 12 (index 12):** 1 `'?'` value – *negligible*, fill with median
# - **Column 13 (index 13):** 376 `'?'` values – **HUGE** (almost 84%!)
# - **Column 14 (index 14):** 1 `'?'` value – *negligible*, fill with median

# %% [markdown]
# ### Strategy
#
# - **Column 13 – REMOVE!** (376/452 = 83% missing!)
#   A column with over 50% missing values is useless and should be dropped.
# - **Other columns – FILL with median**

# %%
# Create clean copy
data_clean = data.copy()

# 1. CHECK COLUMN 13 (index 13) - J angle
col_13 = data_clean.iloc[:, 13]
qm_count_13 = (col_13 == '?').sum()
total_rows = len(data_clean)
missing_percent_13 = (qm_count_13 / total_rows) * 100

print(f"\nColumn 13 (index 13) - J angle:")
print(f"'?' values: {qm_count_13}/{total_rows} ({missing_percent_13:.1f}%)")

if missing_percent_13 > 50:
    print(f"DECISION: DROP this column (>50% missing)")
    print(f"Reason: Too many missing values make this attribute unreliable")
    
    # Drop column 13
    data_clean = data_clean.drop(data_clean.columns[13], axis=1)
    print(f"Column 13 removed")
    print(f"New shape: {data_clean.shape}")
else:
    print(f"DECISION: KEEP and fill with median")

# 2. CLEAN REMAINING COLUMNS (10, 11, 12, 14)
# Note: After dropping column 13, column 14 becomes column 13!

print(f"\n{'='*60}")
print("PROCESSING OTHER COLUMNS:")
print("-"*60)

# Columns to process (adjust indices if column 13 was dropped)
if missing_percent_13 > 50:
    # Column 13 was dropped, so now we have:
    # Old index 10 → still 10
    # Old index 11 → still 11  
    # Old index 12 → still 12
    # Old index 14 → now 13!
    columns_to_clean = [10, 11, 12, 13]  # adjusted indices
else:
    columns_to_clean = [10, 11, 12, 13, 14]

for col_idx in columns_to_clean:
    if col_idx < len(data_clean.columns) - 1: 
        col_name = data_clean.columns[col_idx]
        col = data_clean[col_name]
        
        print(f"\nColumn index {col_idx}:")
        
        # Count '?' before
        qm_before = (col == '?').sum() if col.dtype == 'object' else 0
        print(f"   '?' values before: {qm_before}")
        
        # Step 1: Replace '?' with NaN
        data_clean[col_name] = data_clean[col_name].replace('?', np.nan)
        
        # Step 2: Convert to numeric
        data_clean[col_name] = pd.to_numeric(data_clean[col_name], errors='coerce')
        
        # Step 3: Fill NaN with median
        if data_clean[col_name].isna().any():
            median_val = data_clean[col_name].median()
            nan_count = data_clean[col_name].isna().sum()
            data_clean[col_name].fillna(median_val, inplace=True)
            
            print(f"Replaced {nan_count} missing values with median: {median_val:.2f}")
            print(f"New type: {data_clean[col_name].dtype}")
        else:
            print(f"No missing values")

# 3. FINAL VERIFICATION
print(f"\n{'='*60}")
print("FINAL VERIFICATION:")
print("-"*60)

print(f"Original shape: {data.shape}")
print(f"New shape: {data_clean.shape}")
print(f"Columns removed: {data.shape[1] - data_clean.shape[1]}")

# Check for remaining '?' or NaN
total_nan = data_clean.isna().sum().sum()
print(f"Total NaN remaining: {total_nan}")

# Check data types
print(f"\nData type summary:")
print(data_clean.dtypes.value_counts())

# Save cleaned data
data_clean.to_csv('data_cleaned_columns_10_14.csv', index=False)
print(f"\nCleaned data saved to 'data_cleaned_columns_10_14.csv'")

print(f"\n{'='*60}")
print("SUMMARY OF ACTIONS:")
print("-"*60)
print(f"Column 13 (J angle): REMOVED (83% missing)")
print(f"Column 10 (T angle): Filled 8 missing values with median")
print(f"Column 11 (P angle): Filled 22 missing values with median")
print(f"Column 12 (QRST angle): Filled 1 missing value with median")
print(f"Column 14 (Heart rate): Filled 1 missing value with median")
print(f"All columns converted to numeric type")
print("="*60)
# Out:
# Column 13 (index 13) - J angle:
# '?' values: 376/452 (83.2%)
# DECISION: DROP this column (>50% missing)
# Reason: Too many missing values make this attribute unreliable
# Column 13 removed
# New shape: (452, 279)
#
# ...
# PROCESSING OTHER COLUMNS:
# ------------------------------------------------------------
#
# Column index 10:
#    '?' values before: 8
# Replaced 8 missing values with median: 41.00
# New type: float64
#
# Column index 11:
#    '?' values before: 22
# Replaced 22 missing values with median: 56.00
# New type: float64
#
# Column index 12:
#    '?' values before: 1
# Replaced 1 missing values with median: 40.00
# New type: float64
#
# Column index 13:
#    '?' values before: 1
# Replaced 1 missing values with median: 72.00
# New type: float64
#
# ...
# FINAL VERIFICATION:
# ------------------------------------------------------------
# Original shape: (452, 280)
# New shape: (452, 279)
# Columns removed: 1
# Total NaN remaining: 0
#
# Data type summary:
# int64      159
# ...

# %%
# Define columns according to documentation
col_names = {
    0: 'Age',
    1: 'Sex', 
    2: 'Height',
    3: 'Weight',
    4: 'QRS_duration',
    5: 'PR_interval',
    6: 'QT_interval',
    7: 'T_interval',
    8: 'P_interval',
    13: 'Heart_rate'
}

# 1. CHECK BASIC BIOMETRIC DATA
print("\nBIOMETRIC DATA:")
print("-"*60)

# Age (0-120 years is realistic)
age_col = data_clean.iloc[:, 0]
print("\nAGE (column 0):")
print(f"   Min: {age_col.min()}, Max: {age_col.max()}")
print(f"   Mean: {age_col.mean():.1f}, Std: {age_col.std():.1f}")

# Mask for invalid age values
invalid_age_mask = (age_col < 0) | (age_col > 120)
if invalid_age_mask.any():
    invalid_values = age_col[invalid_age_mask]
    print(f"Found {len(invalid_values)} invalid values!")
    print(f"   Values: {invalid_values.tolist()}")

    # Replace invalid values with median of valid ones
    median_age = age_col[(age_col >= 0) & (age_col <= 120)].median()
    print(f"   Replacing invalid values with median = {median_age}")
    data_clean.iloc[invalid_age_mask.values, 0] = median_age
else:
    print("All values are in valid range (0–120)")

# SEX (0 or 1)
sex_col = data_clean.iloc[:, 1]
print("\nSEX (column 1):")
print(f"   Unique values: {sex_col.unique()}")

# Mask for invalid sex values
invalid_sex_mask = ~sex_col.isin([0, 1])
if invalid_sex_mask.any():
    invalid_values = sex_col[invalid_sex_mask]
    print(f"Found {len(invalid_values)} invalid values!")
    print(f"   Values: {invalid_values.tolist()}")

    # Replace invalid values with the mode (most frequent value)
    mode_sex = sex_col[sex_col.isin([0, 1])].mode().iloc[0]
    print(f"   Replacing invalid values with mode = {mode_sex}")
    data_clean.iloc[invalid_sex_mask.values, 1] = mode_sex
else:
    print("All values are valid (0 or 1)")

# Height (100-250 cm is realistic)
height_col = data_clean.iloc[:, 2]
print(f"\nHEIGHT (column 2):")
print(f"   Min: {height_col.min()}, Max: {height_col.max()}")
print(f"   Mean: {height_col.mean():.1f}, Std: {height_col.std():.1f}")

invalid_mask = (height_col < 100) | (height_col > 250)
invalid_height = data_clean[invalid_mask]

if len(invalid_height) > 0:
    print(f"Found {len(invalid_height)} invalid values!")
    print(f"   Values: {height_col[invalid_mask].tolist()}")

    # Caluculate median
    median_height = height_col[(height_col >= 100) & (height_col <= 250)].median()
    print(f"   Replacing invalid values with median = {median_height}")

    # Replace non valid values with median
    data_clean.iloc[invalid_mask.values, 2] = median_height

else:
    print("All values are in valid range (100–250 cm)")

    
# Weight (30-200 kg is realistic)
weight_col = data_clean.iloc[:, 3]
print("\nWEIGHT (column 3):")
print(f"   Min: {weight_col.min()}, Max: {weight_col.max()}")
print(f"   Mean: {weight_col.mean():.1f}, Std: {weight_col.std():.1f}")

# Mask for invalid weight values
invalid_weight_mask = (weight_col < 30) | (weight_col > 200)
if invalid_weight_mask.any():
    invalid_values = weight_col[invalid_weight_mask]
    print(f"Found {len(invalid_values)} invalid values!")
    print(f"   Values: {invalid_values.tolist()}")

    # Replace invalid values with median of valid ones
    median_weight = weight_col[(weight_col >= 30) & (weight_col <= 200)].median()
    print(f"   Replacing invalid values with median = {median_weight}")
    data_clean.iloc[invalid_weight_mask.values, 3] = median_weight
else:
    print("All values are in valid range (30–200 kg)")

# Heart rate (30-220 beats/min is realistic)
hr_col = data_clean.iloc[:, 13]
print("\nHEART RATE (column 13):")
print(f"   Min: {hr_col.min()}, Max: {hr_col.max()}")
print(f"   Mean: {hr_col.mean():.1f}, Std: {hr_col.std():.1f}")

# Mask for invalid heart rate values
invalid_hr_mask = (hr_col < 30) | (hr_col > 220)
if invalid_hr_mask.any():
    invalid_values = hr_col[invalid_hr_mask]
    print(f"Found {len(invalid_values)} invalid values!")
    print(f"   Values: {invalid_values.tolist()}")

    # Replace invalid values with median of valid ones
    median_hr = hr_col[(hr_col >= 30) & (hr_col <= 220)].median()
    print(f"   Replacing invalid values with median = {median_hr}")
    data_clean.iloc[invalid_hr_mask.values, 13] = median_hr
else:
    print("All values are in valid range (30–220 bpm)")
# Out:
# BIOMETRIC DATA:
# ------------------------------------------------------------
#
# AGE (column 0):
#    Min: 0, Max: 83
#    Mean: 46.5, Std: 16.5
# All values are in valid range (0–120)
#
# SEX (column 1):
#    Unique values: [0 1]
# All values are valid (0 or 1)
#
# HEIGHT (column 2):
#    Min: 105, Max: 780
#    Mean: 166.2, Std: 37.2
# Found 2 invalid values!
#    Values: [780, 608]
#    Replacing invalid values with median = 164.0
#
# WEIGHT (column 3):
#    Min: 6, Max: 176
#    Mean: 68.2, Std: 16.6
# Found 12 invalid values!
#    Values: [10, 18, 6, 25, 10, 12, 28, 25, 22, 21, 24, 29]
#    Replacing invalid values with median = 69.0
#
# HEART RATE (column 13):
#    Min: 44.0, Max: 163.0
#    Mean: 74.5, Std: 13.9
# All values are in valid range (30–220 bpm)

# %%
# Last column is diagnosis (class)
target_col = data_clean.columns[-1]

print("="*60)
print("PROCESSING MINORITY CLASSES")
print("="*60)

# 1. Originalna distribucija
print("\nORIGINAL DISTRIBUTION:")
print("-"*60)

total_instances = len(data_clean)
class_counts = data[target_col].value_counts().sort_index()

for cls in sorted(data_clean[target_col].unique()):
    count = class_counts[cls]
    percent = (count / total_instances) * 100
    print(f"Class {cls:2d}: {count:3d} instances ({percent:5.2f}%)")

# 2. Identify minority classes (< 3%)
minority_threshold = 3.0

print(f"\n{'='*60}")
print(f"MINORITY CLASSES (< {minority_threshold}%):")
print("-"*60)

minority_classes = []
for cls in sorted(data_clean[target_col].unique()):
    count = class_counts[cls]
    percent = (count / total_instances) * 100
    
    if percent < minority_threshold and cls != 16:  # NE diraj klasu 16 (već je Others)
        minority_classes.append(cls)
        print(f"Class {cls:2d}: {count:3d} instanci ({percent:5.2f}%) → TRANSFERS TO 16")

print(f"\nTotal minority classes: {len(minority_classes)}")

# 3. Unite minority classes to 16 (Others)
print(f"\n{'='*60}")
print("UNITE MINORITY CLASSES TO 16 (Others):")
print("-"*60)

# Transfer all minority classes to 16
total_moved = 0
for cls in minority_classes:
    count = (data_clean[target_col] == cls).sum()
    data_clean.loc[data_clean[target_col] == cls, target_col] = 16
    total_moved += count
    print(f"Class {cls:2d} → 16: {count} insstances")

print(f"\nTotal instances transfered: {total_moved}")

# 4. New distribution
print(f"\n{'='*60}")
print("NEW DISTRIBUTION (after uniting):")
print("-"*60)

final_counts = data_clean[target_col].value_counts().sort_index()

for cls in sorted(data_clean[target_col].unique()):
    count = final_counts[cls]
    percent = (count / len(data_clean)) * 100
    
    if cls == 16:
        print(f"Class {cls:2d} (Others): {count:3d} instances ({percent:5.2f}%) ")
    else:
        print(f"Class {cls:2d}: {count:3d} instances ({percent:5.2f}%)")

print(f"\n{'='*60}")
print(f"FINAL RESULT:")
print("-"*60)
print(f"Original number of classes: {data[target_col].nunique()}")
print(f"Final number of classes: {data_clean[target_col].nunique()}")
print(f"Reduction: {data[target_col].nunique() - data_clean[target_col].nunique()} klasa")
print(f"\nFinal classes: {sorted(data_clean[target_col].unique())}")


# 5. Check if some columns have all the same values, if yes remove them
print(f"\n{'='*60}")
print("FIND INFORMATIVE COLUMNS:")
print("-"*60)

min_unique_ratio = 0.05  # 5% (0.01 = 1%, 0.10 = 10%)
informative_cols = []
n_samples = len(data_clean)

for i, col in enumerate(data_clean.columns):
    # Preskoči proveru za poslednju kolonu
    if i == len(data_clean.columns) - 1:
        informative_cols.append(col)
        continue
    
    n_unique = data_clean[col].nunique()
    unique_ratio = n_unique / n_samples
    
    if unique_ratio >= min_unique_ratio:
        informative_cols.append(col)

# Create a new matrix with only informative columns
data_clean_filtered = data_clean[informative_cols].copy()

print(f"\n \nOriginal matrix: {data_clean.shape}")
print(f"New matrix: {data_clean_filtered.shape}")
print(f"Removed columns: {data_clean.shape[1] - data_clean_filtered.shape[1]}")

# 6. Save clean data
data_clean_filtered.to_csv('data_clean_final.csv', index=False)
print(f"\nSaved to 'data_final.csv'")
data_clean_final = data_clean_filtered
# Out:
# ...
# PROCESSING MINORITY CLASSES
# ...
#
# ORIGINAL DISTRIBUTION:
# ------------------------------------------------------------
# Class  1: 245 instances (54.20%)
# Class  2:  44 instances ( 9.73%)
# Class  3:  15 instances ( 3.32%)
# Class  4:  15 instances ( 3.32%)
# Class  5:  13 instances ( 2.88%)
# Class  6:  25 instances ( 5.53%)
# Class  7:   3 instances ( 0.66%)
# Class  8:   2 instances ( 0.44%)
# Class  9:   9 instances ( 1.99%)
# Class 10:  50 instances (11.06%)
# Class 14:   4 instances ( 0.88%)
# Class 15:   5 instances ( 1.11%)
# Class 16:  22 instances ( 4.87%)
#
# ...
# MINORITY CLASSES (< 3.0%):
# ------------------------------------------------------------
# Class  5:  13 instanci ( 2.88%) → TRANSFERS TO 16
# Class  7:   3 instanci ( 0.66%) → TRANSFERS TO 16
# Class  8:   2 instanci ( 0.44%) → TRANSFERS TO 16
# Class  9:   9 instanci ( 1.99%) → TRANSFERS TO 16
# Class 14:   4 instanci ( 0.88%) → TRANSFERS TO 16
# Class 15:   5 instanci ( 1.11%) → TRANSFERS TO 16
#
# ...

# %% [markdown]
# ## 2) Feature selection

# %%
def calculateInfoD(col):
    un = np.unique(col)
    infoD = 0
    for u in un:
        p = sum(col == u)/len(col)
        infoD -= p*np.log2(p)
    return infoD

# %%
def informationGain(feat):
    numberOfSteps = 10
    classes = data_clean_final.iloc[:, -1]
    infoD = calculateInfoD(classes)
    
    col = data_clean_final.iloc[:, feat]
    f = np.unique(col)
    
    if len(f) > numberOfSteps:
            step = (max(col) - min(col))/numberOfSteps
            col = np.floor(col/step)*step
            f = np.unique(col)
                
    infoDA = 0
    for i in f:
        mask = (col == i).values 
        temp = classes.iloc[mask]
    
        infoDi = calculateInfoD(temp)
        Di = sum(mask)
        D = len(col)

        infoDA += Di*infoDi/D
        
    return infoD - infoDA

# %%
# Calculate average Information Gain for each column
# Each column's IG is measured against all other columns
columns = data_clean_final.columns
n_cols = len(columns)

# Store IG for each column
info_gains = []

for col in range(data_clean_final.shape[1]-1):
    
    # Calculate IG
    info_gains.append(informationGain(col))

# Create results dataframe
feature_importance = pd.DataFrame({
    'Index': range(len(info_gains)),  # Column index
    'Column': columns[:-1],
    'Average_Information_Gain': info_gains
}).sort_values(by='Average_Information_Gain', ascending=False)

# Select top 10
top_10 = feature_importance.head(10)

print("TOP 10 COLUMNS BY AVERAGE INFORMATION GAIN:")
print("=" * 60)
print(top_10.to_string(index=False))
print("\n")

# Print just the column names
print("\nSELECTED COLUMN NAMES:")
print(top_10['Column'].tolist())
# Out:
# TOP 10 COLUMNS BY AVERAGE INFORMATION GAIN:
# ...
#  Index     Column  Average_Information_Gain
#     12 heart_rate                  0.347994
#     97         JR                  0.331186
#    122         LE                  0.314144
#     23         EB                  0.310474
#      9          T                  0.300626
#     40         GU                  0.295567
#     57         HR                  0.291330
#    115         KS                  0.288737
#     20         DA                  0.273138
#     21         DD                  0.265670
#
#
#
# SELECTED COLUMN NAMES:
# ['heart_rate', 'JR', 'LE', 'EB', 'T', 'GU', 'HR', 'KS', 'DA', 'DD']

# %%
wanted_col = top_10['Column'].values
wanted_col = np.append(wanted_col, data_clean_final.columns[-1])

# Save final data
data_final = data_clean_final[wanted_col]
data_final.head(10)

data_final.to_csv('data_final.csv', index=False)
print(f"Saved to 'data_final.csv'")

top_indices = top_10.index

print("TOP 10 columns:")
for idx in top_indices:
    col_name = data_clean_final.columns[idx]
    print(f"- Index {idx}: {col_name}")
# Out:
# Saved to 'data_final.csv'
# TOP 10 columns:
# - Index 12: heart_rate
# - Index 97: JR
# - Index 122: LE
# - Index 23: EB
# - Index 9: T
# - Index 40: GU
# - Index 57: HR
# - Index 115: KS
# - Index 20: DA
# - Index 21: DD

# %% [markdown]
# ### Calculate spearman correlation

# %%
def calculate_rank(data):
    ranked_data = np.zeros(data.shape)
    sorted_data = sorted(data)

    val, cnt = np.unique(sorted_data, return_counts = True)

    r = 1
    for i in range(len(val)):
        rank = np.mean(np.arange(r, r+cnt[i]))
        pos = np.where(data == val[i])
        ranked_data[pos] = rank
        
        r += cnt[i]
        
    return ranked_data

# %%
def spearman_correlation(x, y):
    rank_x = calculate_rank(x)
    rank_y = calculate_rank(y)

    spearman = np.cov(rank_x, rank_y)[0,1]/np.std(rank_x)/np.std(rank_y)

    return spearman

# %%
# Get column names
cols = data_final.columns
n = len(cols)

# Create an empty correlation matrix
corr_matrix = np.zeros((n, n))

# Fill the correlation matrix
for i in range(n):
    for j in range(n):
        corr_matrix[i, j] = spearman_correlation(data[cols[i]], data[cols[j]])

# Convert to DataFrame for better display
corr_df = pd.DataFrame(corr_matrix, index=cols, columns=cols)
#print(corr_df)

plt.figure(figsize=(11, 11))
sns.heatmap(corr_df, annot = True, fmt='.2f',cmap='coolwarm')
plt.yticks(rotation=0)
plt.show()

# %%
# 1. Identify the top 2 features most correlated with the class
class_corr = corr_df['diagnosis'].drop('diagnosis')  # exclude correlation of class with itself

# Take the two features with the highest absolute correlation
top2_features = class_corr.abs().sort_values(ascending=False).head(2).index.tolist()
print("Top 2 features most correlated with class:", top2_features)


# 2. Create scatter plot of samples colored by class using these two features
plt.figure(figsize=(8,6))
sns.scatterplot(
    data=data_final,
    x=data_final[top2_features[0]] + np.random.uniform(-1, 1, size=len(data_final)),
    y=data_final[top2_features[1]] + np.random.uniform(-1, 1, size=len(data_final)),
    hue='diagnosis',           # color by class
    palette='Set1',
    s=60                   # marker size
)
plt.title(f"Distribution of samples by class using {top2_features[0]} and {top2_features[1]}")
plt.show()
# Out:
# Top 2 features most correlated with class: ['DA', 'DD']

# %% [markdown]
# ## 3) Dimension reduction (LDA tranformation)

# %%
def parameters(X, y, Class):
    # p = prior probability (n_class / n_total)
    # M = mean vector for class c (shape: n_features x 1)
    # S = covariance matrix for class c (shape: n_features x n_features)
    Xk = X.loc[y==Class, :]
    p = Xk.shape[0]/X.shape[0]
    M = Xk.mean().values.reshape(Xk.shape[1],1)
    S = Xk.cov()

    return (p, M, S)

# %%
def standardize(X):
    # Calculate mean and std for each feature
    mean = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    
    # Avoid division by zero (if std=0, keep original values)
    std[std == 0] = 1
    
    # Standardize: (X - mean) / std
    X_scaled = (X - mean) / std
    
    return X_scaled, mean, std

# %%
import scipy.linalg

# Get unique classes
X = data_clean_final.iloc[:, :-1]
X_scaled, X_mean, X_std = standardize(X)
X_scaled.to_csv('input_data_standardized.csv', index=False)
print(f"Saved to 'input_data_standardized.csv'")

y = data_clean_final['diagnosis'].values
classes = np.unique(y)
n_features = X.shape[1]
n_samples = X.shape[0]

# Initialize scatter matrices
Sw = np.zeros((n_features, n_features))  # Within-class scatter matrix
Sb = np.zeros((n_features, n_features))  # Between-class scatter matrix

# Calculate overall mean
overall_mean = X_scaled.mean(axis=0).values.reshape(n_features, 1)

print("Calculating scatter matrices for each class")

# Loop through each class
for c in classes:
    # Get parameters for this class
    p, M, S = parameters(X_scaled, y, c)
    
    # Within-class scatter:
    Sw += p * S
    
    # Between-class scatter:
    mean_diff = M - overall_mean
    Sb += p * (mean_diff @ mean_diff.T)
    
    print(f"  Class {c}: p={p:.4f}, processed")

print("\nScatter matrices calculated")
print(f" Sw shape: {Sw.shape}")
print(f" Sb shape: {Sb.shape}")

S = np.linalg.pinv(Sw)@Sb
eigval, eigvec = np.linalg.eig(S)
# Out:
# Saved to 'input_data_standardized.csv'
# Calculating scatter matrices for each class
#   Class 1: p=0.5420, processed
#   Class 2: p=0.0973, processed
#   Class 3: p=0.0332, processed
#   Class 4: p=0.0332, processed
#   Class 6: p=0.0553, processed
#   Class 10: p=0.1106, processed
#   Class 16: p=0.1283, processed
#
# Scatter matrices calculated
#  Sw shape: (125, 125)
#  Sb shape: (125, 125)

# %%
print("=" * 70)
print("EIGENVALUES AND EIGENVECTORS")
print("=" * 70)

# Sort eigenvalues and eigenvectors in descending order
idx = eigval.argsort()[::-1]  # Descending order indices
eigval_sorted = eigval[idx]
eigvec_sorted = eigvec[:, idx]

# Filter out zero eigenvalues (keep only non-zero ones)
threshold = 1e-10
non_zero_idx = np.abs(eigval) > threshold
eigval_nonzero = eigval[non_zero_idx]
eigvec_nonzero = eigvec[:, non_zero_idx]

eigvec_nonzero = np.real(eigvec_nonzero)
eigval_nonzero = np.real(eigval_nonzero)

print("NON-ZERO EIGENVALUES")

print(f"\nNumber of non-zero eigenvalues: {len(eigval_nonzero)}")

for i, val in enumerate(eigval_nonzero):
    print(f"λ_{i+1} = {val:.6f}")

# Calculate explained variance ratio
total_variance = np.sum(eigval_nonzero) 
explained_variance = eigval_nonzero / total_variance
cumulative_variance = np.cumsum(explained_variance)

# Find minimum components for 80% variance
threshold_pct = 0.80
min_components = np.argmax(cumulative_variance >= threshold_pct) + 1

print(f"\n{'=' * 70}")
print(f"RESULT: Minimum components for >{threshold_pct*100:.0f}% variance: {min_components}")
print(f"Cumulative variance: {cumulative_variance[min_components-1]*100:.2f}%")
print(f"{'=' * 70}")
# Out:
# ...
# EIGENVALUES AND EIGENVECTORS
# ...
# NON-ZERO EIGENVALUES
#
# Number of non-zero eigenvalues: 6
# λ_1 = 3.620987
# λ_2 = 2.099197
# λ_3 = 1.437803
# λ_4 = 1.177866
# λ_5 = 0.707940
# λ_6 = 0.598107
#
# ...
# RESULT: Minimum components for >80% variance: 4
# Cumulative variance: 86.45%
# ...

# %%
# Transform data to 4 dimensions
n_components = 4
W = eigvec_nonzero[:, :n_components]  # First 4 eigenvectors

X_scaled_array = X_scaled.values

X_lda = X_scaled_array @ W  # Transform data

print(f"Original data shape: {X_scaled.shape}")
print(f"Transformed data shape: {X_lda.shape}")

# Create DataFrame with transformed data
lda_columns = [f'LDA_{i+1}' for i in range(n_components)]
data_lda_transformed = pd.DataFrame(X_lda, columns=lda_columns)
data_lda_transformed['diagnosis'] = y

print("\nTransformed dataset ready for classification!")
print(data_lda_transformed.head())
# Out:
# Original data shape: (452, 125)
# Transformed data shape: (452, 4)
#
# Transformed dataset ready for classification!
#       LDA_1     LDA_2     LDA_3     LDA_4  diagnosis
# 0 -0.038503 -0.230888 -0.127930  0.061700         16
# 1 -0.251980 -0.031081  0.127606 -0.159821          6
# 2 -0.134917 -1.349067 -0.231117  0.198470         10
# 3  0.118987 -0.035785  0.115649 -0.012719          1
# 4 -0.039921 -0.015797  0.183133  0.279802         16

# %% [markdown]
# ## 4) Hypothesis testing and parametric classification

# %%
from sklearn.model_selection import train_test_split

print("=" * 80)
print("PARAMETRIC CLASSIFICATION")
print("=" * 80)

# Prepare data
X = data_lda_transformed[['LDA_1', 'LDA_2', 'LDA_3', 'LDA_4']].values
y = data_lda_transformed['diagnosis'].values

X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.3,      # 30% for tesing
    random_state=42,   
    stratify=y 
)

print(f"\nTotal samples: {len(X)}")
print(f"Number of classes: {len(np.unique(y))}")

classes = np.unique(y_train)
class_params = {}

for c in classes:
    X_c = X_train[y_train == c]
    n_c = len(X_c)
    
    mean = np.mean(X_c, axis=0)
    cov = np.cov(X_c, rowvar=False) + np.eye(X.shape[1]) * 1e-6
    prior = n_c / len(y_train)
    
    class_params[c] = {'mean': mean, 'cov': cov, 'prior': prior, 'n': n_c}

    print(f"\nClass {c}:")
    print(f"  Training samples: {n_c}")
    print(f"  Prior: {prior:.4f}")
# Out:
# ...
# PARAMETRIC CLASSIFICATION
# ...
#
# Total samples: 452
# Number of classes: 7
#
# Class 1:
#   Training samples: 171
#   Prior: 0.5411
#
# Class 2:
#   Training samples: 31
#   Prior: 0.0981
#
# Class 3:
#   Training samples: 10
#   Prior: 0.0316
#
# Class 4:
#   Training samples: 11
#   Prior: 0.0348
#
# Class 6:
#   Training samples: 17
#   Prior: 0.0538
#
# Class 10:
#   Training samples: 35
#   Prior: 0.1108
#
# Class 16:
#   Training samples: 41
#   Prior: 0.1297

# %%
def classify_bayes(x, class_params, classes):
    #Classify using Bayes' theorem with Maximum A Posteriori(MAP)
    likelihoods = {}
    
    # Calculate likelihood p(x|C) for each class
    for c in classes:
        likelihoods[c] = multivariate_normal.pdf(
            x, mean=class_params[c]['mean'], cov=class_params[c]['cov']
        )
    
    # Calculate evidence p(x)
    evidence = sum(likelihoods[c] * class_params[c]['prior'] for c in classes)
    if evidence == 0:
        evidence = 1e-10
    
    # Calculate posterior P(C|x)
    posteriors = {c: (likelihoods[c] * class_params[c]['prior']) / evidence 
                  for c in classes}
    
    pred_class = max(posteriors, key=posteriors.get)
    return pred_class, likelihoods, posteriors

# %%
from scipy.stats import multivariate_normal

y_pred = []
all_posteriors = []

for i in range(len(X_test)):
    pred, lik, post = classify_bayes(X_test[i], class_params, classes)
    y_pred.append(pred)
    all_posteriors.append(post)

y_pred = np.array(y_pred)

# Calculate accuracy
accuracy_ht_overall = np.mean(y_pred == y_test)
n_correct = np.sum(y_pred == y_test)
n_total = len(y_test)

print(f"\nClassification Results:")
print(f"  Correct predictions: {n_correct}/{n_total}")
print(f"  Overall Accuracy: {accuracy_ht_overall:.4f} ({accuracy_ht_overall*100:.2f}%)")
# Out:
# Classification Results:
#   Correct predictions: 111/136
#   Overall Accuracy: 0.8162 (81.62%)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
unique_classes = sorted(np.unique(y_test))

plt.figure(figsize=(10, 8))

sns.heatmap(cm, 
            annot=True,     
            fmt='d',    
            cmap='Blues',         
            square=True,         
            cbar_kws={'label': 'Number of Samples'},
            xticklabels=unique_classes,
            yticklabels=unique_classes,
            linewidths=0.5,      
            linecolor='gray')

plt.title(f'Confusion Matrix - Parametric Classification\nOverall Accuracy: {accuracy_ht_overall:.4f} ({accuracy_ht_overall*100:.2f}%)', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Predicted Class', fontsize=13, fontweight='bold')
plt.ylabel('True Class', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

print(f"\n{'Class':<8} {'Precision':<12} {'Recall':<12} {'Specificity':<12} {'Accuracy':<12}")
print("-" * 80)

precision_list_ht = []
sensitivity_list_ht = []
specificity_list_ht = []
accuracy_list_ht = []

for idx, c in enumerate(unique_classes):
    TP = cm[idx, idx]
    FP = cm[:, idx].sum() - TP
    FN = cm[idx, :].sum() - TP
    TN = cm.sum() - (TP + FP + FN)
    
    precision_ht = TP / (TP + FP) if (TP + FP) > 0 else 0
    sensitivity_ht = TP / (TP + FN) if (TP + FN) > 0 else 0
    specificity_ht = TN / (TN + FP) if (TN + FP) > 0 else 0
    accuracy_ht = (TP+TN)/(TP+TN+FP+FN) if (TP+TN+FP+FN) else 0
    
    precision_list_ht.append(precision_ht)
    sensitivity_list_ht.append(sensitivity_ht)
    specificity_list_ht.append(specificity_ht)
    accuracy_list_ht.append(accuracy_ht)
    
    print(f"{c:<8d} {precision_ht:<12.4f} {sensitivity_ht:<12.4f} {specificity_ht:<12.4f} {accuracy_ht:<12.4f}")

print("-" * 80)
print(f"{'AVERAGE':<8} {np.mean(precision_list_ht):<12.4f} {np.mean(sensitivity_list_ht):<12.4f} "
      f"{np.mean(specificity_list_ht):<12.4f} {np.mean(accuracy_list_ht):<12.4f}")
print("=" * 80)
# Out:
# Class    Precision    Recall       Specificity  Accuracy
# --------------------------------------------------------------------------------
# 1        0.8590       0.9054       0.8226       0.8676
# 2        0.7500       0.4615       0.9837       0.9338
# 3        0.8333       1.0000       0.9924       0.9926
# 4        0.6667       1.0000       0.9848       0.9853
# 6        0.6667       0.5000       0.9844       0.9559
# 10       1.0000       1.0000       1.0000       1.0000
# 16       0.5882       0.5882       0.9412       0.8971
# --------------------------------------------------------------------------------
# AVERAGE  0.7663       0.7793       0.9584       0.9475
# ...

# %% [markdown]
# ## Multiple Hypothesis Test with Linear Discriminant Analysis (LDA)
#
# LDA + Multiple Hypothesis Test method achieves high accuracy, around 82%, which is an expected outcome given the characteristics of the dataset. LDA + Multiple Hypothesis Test is a parametric classifier that assumes normally distributed data and equal covariance matrices across classes. Despite these assumptions, it performs remarkably well on small and high-dimensional datasets, because it simultaneously performs dimensionality reduction and supervised projection that maximizes class separability. In this case, with ~400 samples and 125 features, LDA is able to extract the most discriminative linear combinations of features, reducing noise and mitigating the effects of overfitting. Therefore, it's strong performance indicates that the classes are likely linearly separable in the transformed space and that the model effectively captures the main directions of variability among classes.

# %% [markdown]
# ## 5) Nonparametric classification

# %%
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

X = data_clean_final.drop(columns = 'diagnosis')
Y = data_clean_final['diagnosis']

# Spliting data into test and training groups
Xtraining, Xtest, Ytraining, Ytest = train_test_split(X, Y, train_size = 2/3, random_state = 42, stratify = Y)

print("=" * 80)
print("KNN CLASSIFICATION WITH CROSS-VALIDATION")
print("=" * 80)

# ========================================
# Data normalization for KNN
# ========================================
scaler = StandardScaler()
Xtraining_scaled = scaler.fit_transform(Xtraining)
Xtest_scaled = scaler.transform(Xtest)

print(f"\nTraining samples: {len(Xtraining)}")
print(f"Test samples: {len(Xtest)}")
print(f"Number of features: {Xtraining.shape[1]}")
print(f"Number of classes: {len(np.unique(Ytraining))}")

#Visualisation of the split
Ytraining.hist()
Ytest.hist()
# Out:
# ...
# KNN CLASSIFICATION WITH CROSS-VALIDATION
# ...
#
# Training samples: 301
# Test samples: 151
# Number of features: 125
# Number of classes: 7
# <Axes: >

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix


# ========================================
# K parameter optimization with CROSS-VALIDATION
# ========================================
k = np.arange(1, 100, 1)
acc_cv = np.zeros((k.size,))
acc_test = np.zeros((k.size,))

print(f"\nOptimizing K parameter using 5-fold cross-validation")
print(f"Testing K values from {k[0]} to {k[-1]}")

for i in range(k.size):
    knn_model = KNN(n_neighbors=k[i])
    
    # CROSS-VALIDATION on training set (5-fold)
    cv_scores = cross_val_score(knn_model, Xtraining_scaled, Ytraining, 
                                cv=5, scoring='accuracy')
    acc_cv[i] = cv_scores.mean()
    
    # Also test on test set (for comparison only)
    knn_model.fit(Xtraining_scaled, Ytraining)
    acc_test[i] = accuracy_score(Ytest, knn_model.predict(Xtest_scaled))

# Find optimal K based on cross-validation
optimal_k_idx = np.argmax(acc_cv)
optimal_k = k[optimal_k_idx]
optimal_cv_score = acc_cv[optimal_k_idx]
optimal_test_score = acc_test[optimal_k_idx]

print(f"\n{'='*80}")
print(f"OPTIMAL K PARAMETER (from cross-validation):")
print(f"  K = {optimal_k}")
print(f"  Cross-validation accuracy: {optimal_cv_score:.4f} ({optimal_cv_score*100:.2f}%)")
print(f"  Test set accuracy: {optimal_test_score:.4f} ({optimal_test_score*100:.2f}%)")
print(f"{'='*80}")

# ========================================
# Plot: CV accuracy vs K
# ========================================
plt.figure(figsize=(14, 5))

# Subplot 1: Cross-validation scores
plt.subplot(1, 2, 1)
plt.plot(k, acc_cv, 'b-', linewidth=2, label='Cross-validation accuracy')
plt.axvline(optimal_k, color='red', linestyle='--', linewidth=2, 
            label=f'Optimal K={optimal_k}')
plt.axhline(optimal_cv_score, color='red', linestyle=':', alpha=0.5)
plt.xlabel('Number of Neighbors (K)', fontsize=12, fontweight='bold')
plt.ylabel('Cross-Validation Accuracy', fontsize=12, fontweight='bold')
plt.title('KNN: Cross-Validation Accuracy vs K', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.legend()

# Subplot 2: Comparison CV vs Test
plt.subplot(1, 2, 2)
plt.plot(k, acc_cv, 'b-', linewidth=2, label='CV accuracy (train)')
plt.plot(k, acc_test, 'g--', linewidth=2, label='Test accuracy')
plt.axvline(optimal_k, color='red', linestyle='--', linewidth=2, 
            label=f'Optimal K={optimal_k}')
plt.xlabel('Number of Neighbors (K)', fontsize=12, fontweight='bold')
plt.ylabel('Accuracy', fontsize=12, fontweight='bold')
plt.title('KNN: CV vs Test Accuracy', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Optimizing K parameter using 5-fold cross-validation...
# Testing K values from 1 to 99
#
# ...
# OPTIMAL K PARAMETER (from cross-validation):
#   K = 4
#   Cross-validation accuracy: 0.5946 (59.46%)
#   Test set accuracy: 0.5762 (57.62%)
# ...

# %%
# ========================================
# Train final model with optimal K
# ========================================
print(f"\nTraining final KNN model with K={optimal_k}...")
final_knn = KNN(n_neighbors=optimal_k)
final_knn.fit(Xtraining_scaled, Ytraining)

# Prediction on test set
y_pred_knn = final_knn.predict(Xtest_scaled)
final_accuracy_knn = accuracy_score(Ytest, y_pred_knn)

print(f"\n{'='*80}")
print(f"FINAL MODEL PERFORMANCE ON TEST SET")
print(f"{'='*80}")
print(f"K = {optimal_k}")
print(f"Test Accuracy: {final_accuracy_knn:.4f} ({final_accuracy_knn*100:.2f}%)")
print(f"Correct predictions: {np.sum(y_pred_knn == Ytest)}/{len(Ytest)}")

# ========================================
# Confusion Matrix
# ========================================
cm = confusion_matrix(Ytest, y_pred_knn)
unique_classes = sorted(np.unique(Ytest))

plt.figure(figsize=(10, 8))
sns.heatmap(cm, 
            annot=True, fmt='d', cmap='Blues', square=True,
            cbar_kws={'label': 'Number of Samples'},
            xticklabels=unique_classes,
            yticklabels=unique_classes,
            linewidths=0.5, linecolor='gray')

plt.title(f'Confusion Matrix - KNN (K={optimal_k})\n'
          f'Test Accuracy: {final_accuracy_knn:.4f} ({final_accuracy_knn*100:.2f}%)', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Predicted Class', fontsize=13, fontweight='bold')
plt.ylabel('True Class', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# ========================================
# Per-class metrics
# ========================================
print(f"\n{'Class':<8} {'Precision':<12} {'Sensitivity':<12} {'Specificity':<12} {'Accuracy':<12}")
print("-" * 80)

precision_list_knn = []
sensitivity_list_knn = []
specificity_list_knn = []
accuracy_list_knn = []

for idx, c in enumerate(unique_classes):
    TP = cm[idx, idx]
    FP = cm[:, idx].sum() - TP
    FN = cm[idx, :].sum() - TP
    TN = cm.sum() - (TP + FP + FN)
    
    precision_knn = TP / (TP + FP) if (TP + FP) > 0 else 0
    sensitivity_knn = TP / (TP + FN) if (TP + FN) > 0 else 0
    specificity_knn = TN / (TN + FP) if (TN + FP) > 0 else 0
    class_accuracy_knn = (TP + TN) / (TP + TN + FP + FN) if (TP + TN + FP + FN) > 0 else 0
    
    precision_list_knn.append(precision_knn)
    sensitivity_list_knn.append(sensitivity_knn)
    specificity_list_knn.append(specificity_knn)
    accuracy_list_knn.append(class_accuracy_knn)
    
    print(f"{c:<8d} {precision_knn:<12.4f} {sensitivity_knn:<12.4f} {specificity_knn:<12.4f} {class_accuracy_knn:<12.4f}")

# Weighted average
weights_knn = [np.sum(Ytest == c) for c in unique_classes]
total = sum(weights_knn)
weighted_precision_knn = sum(p*w for p,w in zip(precision_list_knn, weights_knn)) / total
weighted_sensitivity_knn = sum(r*w for r,w in zip(sensitivity_list_knn, weights_knn)) / total
weighted_specificity_knn = sum(s*w for s,w in zip(specificity_list_knn, weights_knn)) / total
weighted_accuracy_knn = sum(a*w for a,w in zip(accuracy_list_knn, weights_knn)) / total

print("-" * 80)
print(f"{'MACRO AVG':<8} {np.mean(precision_list_knn):<12.4f} {np.mean(sensitivity_list_knn):<12.4f} "
      f"{np.mean(specificity_list_knn):<12.4f} {np.mean(accuracy_list_knn):<12.4f}")
print(f"{'WEIGHTED':<8} {weighted_precision_knn:<12.4f} {weighted_sensitivity_knn:<12.4f} "
      f"{weighted_specificity_knn:<12.4f} {weighted_accuracy_knn:<12.4f}")
print("=" * 80)
# Out:
# Training final KNN model with K=4...
#
# ...
# FINAL MODEL PERFORMANCE ON TEST SET
# ...
# K = 4
# Test Accuracy: 0.5762 (57.62%)
# Correct predictions: 87/151

# %% [markdown]
# ## k-Nearest Neighbors (kNN)
#
# -The k-Nearest Neighbors classifier produces an accuracy of about 58%, with most samples incorrectly classified into the dominant class. This result is expected, as kNN is a nonparametric, instance-based method that heavily relies on the local structure of the data. In high-dimensional spaces, distance measures such as the Euclidean distance lose discriminative power — a phenomenon known as the curse of dimensionality. With 125 attributes and only ~400 samples, the distances between points become less meaningful, causing kNN to fail in identifying the true neighbors of each instance. Additionally, the severe class imbalance biases the majority vote toward the most frequent class, further explaining why nearly all samples were assigned to class 1.

# %% [markdown]
# ### Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# ========================================
# Optimization: Find best max_depth
# ========================================
depths = np.arange(1, 30, 1)
acc_training = np.zeros((depths.size,))
acc_test = np.zeros((depths.size,))
acc_cv = np.zeros((depths.size,))

print(f"\nTesting max_depth from {depths[0]} to {depths[-1]}...")
print("Using 5-fold cross-validation for optimal depth selection")

for i in range(depths.size):
    dt_model = DecisionTreeClassifier(
        max_depth=depths[i],
        random_state=42
    )
    
    # Cross-validation on training set
    cv_scores = cross_val_score(dt_model, Xtraining, Ytraining, 
                                cv=5, scoring='accuracy')
    acc_cv[i] = cv_scores.mean()
    
    # Fit on training set
    dt_model.fit(Xtraining, Ytraining)
    
    # Calculate accuracies
    acc_test[i] = accuracy_score(Ytest, dt_model.predict(Xtest))
    acc_training[i] = accuracy_score(Ytraining, dt_model.predict(Xtraining))

# Find best depth based on cross-validation
best_acc_cv = np.max(acc_cv)
best_depth_cv = depths[np.argmax(acc_cv)]

# Find best depth based on test set (for comparison)
best_acc_test = np.max(acc_test)
best_depth_test = depths[np.argmax(acc_test)]

print(f"\n{'='*80}")
print("OPTIMAL MAX_DEPTH:")
print(f"  Based on Cross-Validation: depth={best_depth_cv}, accuracy={best_acc_cv*100:.2f}%")
print(f"  Based on Test Set:         depth={best_depth_test}, accuracy={best_acc_test*100:.2f}%")
print(f"{'='*80}")
# Out:
# Testing max_depth from 1 to 29...
# Using 5-fold cross-validation for optimal depth selection
#
# ...
# OPTIMAL MAX_DEPTH:
#   Based on Cross-Validation: depth=5, accuracy=69.11%
#   Based on Test Set:         depth=5, accuracy=67.55%
# ...

# %%
# Use CV-based depth for final model
optimal_depth = best_depth_cv

# ========================================
# Plot: Accuracy vs max_depth
# ========================================
plt.figure(figsize=(14, 5))

# Plot 1: Training vs Test accuracy
plt.subplot(1, 2, 1)
plt.plot(depths, acc_training, 'b-', linewidth=2, label='Training')
plt.plot(depths, acc_test, 'g--', linewidth=2, label='Test')
plt.axvline(optimal_depth, color='red', linestyle='--', linewidth=2, 
            label=f'Optimal depth={optimal_depth}')
plt.xlabel('Tree Depth', fontsize=12, fontweight='bold')
plt.ylabel('Accuracy', fontsize=12, fontweight='bold')
plt.title('Decision Tree: Training vs Test Accuracy', fontsize=14, fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)

# Plot 2: CV vs Test accuracy
plt.subplot(1, 2, 2)
plt.plot(depths, acc_cv, 'b-', linewidth=2, label='Cross-Validation')
plt.plot(depths, acc_test, 'g--', linewidth=2, label='Test')
plt.axvline(optimal_depth, color='red', linestyle='--', linewidth=2, 
            label=f'Optimal depth={optimal_depth}')
plt.xlabel('Tree Depth', fontsize=12, fontweight='bold')
plt.ylabel('Accuracy', fontsize=12, fontweight='bold')
plt.title('Decision Tree: CV vs Test Accuracy', fontsize=14, fontweight='bold')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print(f"\nBest accuracy is achieved with tree depth {optimal_depth} and is {best_acc_cv*100:.2f}%.")
# Out:
# Best accuracy is achieved with tree depth 5 and is 69.11%.

# %%
# ========================================
# Train final model with optimal depth
# ========================================
classifier = DecisionTreeClassifier(
    max_depth=optimal_depth,
    class_weight='balanced',
    random_state=42
)
classifier = classifier.fit(Xtraining, Ytraining)
y_pred_dt = classifier.predict(Xtest)

final_accuracy_dt = accuracy_score(Ytest, y_pred_dt)

print(f"\n{'='*80}")
print("FINAL MODEL PERFORMANCE ON TEST SET")
print(f"{'='*80}")
print(f"Max depth: {optimal_depth}")
print(f"Test accuracy: {final_accuracy_dt*100:.2f}%")
print(f"Correct predictions: {np.sum(y_pred_dt == Ytest)}/{len(Ytest)}")

# ========================================
# Confusion Matrix
# ========================================
conf_mat = confusion_matrix(Ytest, y_pred_dt)
unique_classes = sorted(np.unique(Ytest))

plt.figure(figsize=(10, 8))
sns.heatmap(conf_mat, 
            annot=True, 
            fmt='d', 
            cmap='Greens',
            square=True,
            cbar_kws={'label': 'Number of Samples'},
            xticklabels=unique_classes,
            yticklabels=unique_classes,
            linewidths=0.5,
            linecolor='gray')
plt.title(f'Confusion Matrix - Decision Tree (max_depth={optimal_depth})\n'
          f'Test Accuracy: {final_accuracy_dt:.4f} ({final_accuracy_dt*100:.2f}%)', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Predicted Class', fontsize=13, fontweight='bold')
plt.ylabel('True Class', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# ========================================
# Per-class metrics
# ========================================
print(f"\n{'Class':<8} {'Precision':<12} {'Recall':<12} {'Specificity':<12} {'Accuracy':<12}")
print("-" * 80)

precision_list_dt = []
sensitivity_list_dt = []
specificity_list_dt = []
accuracy_list_dt = []

for idx, c in enumerate(unique_classes):
    TP = conf_mat[idx, idx]
    FP = conf_mat[:, idx].sum() - TP
    FN = conf_mat[idx, :].sum() - TP
    TN = conf_mat.sum() - (TP + FP + FN)
    
    
    precision_dt = TP / (TP + FP) if (TP + FP) > 0 else 0
    sensitivity_dt = TP / (TP + FN) if (TP + FN) > 0 else 0
    specificity_dt = TN / (TN + FP) if (TN + FP) > 0 else 0
    class_accuracy_dt = (TP + TN) / (TP + TN + FP + FN) if (TP + TN + FP + FN) > 0 else 0
    
    precision_list_dt.append(precision_dt)
    sensitivity_list_dt.append(sensitivity_dt)
    specificity_list_dt.append(specificity_dt)
    accuracy_list_dt.append(class_accuracy_dt)
    
    print(f"{c:<8d} {precision_dt:<12.4f} {sensitivity_dt:<12.4f} {specificity_dt:<12.4f} {class_accuracy_dt:<12.4f}")

# Weighted average
weights_dt = [np.sum(Ytest == c) for c in unique_classes]
total = sum(weights_dt)
weighted_precision_dt = sum(p*w for p,w in zip(precision_list_dt, weights_dt)) / total
weighted_sensitivity_dt = sum(r*w for r,w in zip(sensitivity_list_dt, weights_dt)) / total
weighted_specificity_dt = sum(s*w for s,w in zip(specificity_list_dt, weights_dt)) / total
weighted_accuracy_dt = sum(a*w for a,w in zip(accuracy_list_knn, weights_dt)) / total


print("-" * 80)
print(f"{'MACRO AVG':<8} {np.mean(precision_list_dt):<12.4f} {np.mean(sensitivity_list_dt):<12.4f} "
      f"{np.mean(specificity_list_dt):<12.4f} {np.mean(accuracy_list_dt):<12.4f}")
print(f"{'WEIGHTED':<8} {weighted_precision_dt:<12.4f} {weighted_sensitivity_dt:<12.4f} "
      f"{weighted_specificity_dt:<12.4f} {weighted_accuracy_dt:<12.4f}")
print("=" * 80)
# Out:
# ...
# FINAL MODEL PERFORMANCE ON TEST SET
# ...
# Max depth: 5
# Test accuracy: 67.55%
# Correct predictions: 102/151
# Class    Precision    Recall       Specificity  Accuracy
# --------------------------------------------------------------------------------
# 1        0.7634       0.8659       0.6812       0.7815
# 2        0.6000       0.6000       0.9559       0.9205
# 3        0.7143       1.0000       0.9863       0.9868
# 4        0.2500       0.4000       0.9589       0.9404
# 6        0.7778       0.8750       0.9860       0.9801
# 10       0.4286       0.3529       0.9403       0.8742
# 16       0.4000       0.1053       0.9773       0.8675
# --------------------------------------------------------------------------------
# MACRO AVG 0.5620       0.5999       0.9265       0.9073
# WEIGHTED 0.6459       0.6755       0.8103       0.6755
# ...

# %%
# Visualize the tree
# ========================================
fig = plt.figure(figsize=(50, 25))  # Masivna širina

tree.plot_tree(classifier, 
               feature_names=Xtraining.columns,
               class_names=[str(c) for c in sorted(unique_classes)],
               filled=True,
               fontsize=7,
               proportion=True,
               precision=2,
               rounded=True)

plt.subplots_adjust(left=0.01, right=0.99, top=0.97, bottom=0.03)
plt.savefig('decision_tree_ultra_wide.png', dpi=200, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %% [markdown]
# ## Decision Tree
#
# The Decision Tree classifier achieves medium low performance, around 67%, with most samples incorrectly classified into the dominant class. This behavior is typical when the dataset is small, unbalanced, and high-dimensional. Decision Trees tend to overfit the training data by creating overly complex decision boundaries that do not generalize to unseen samples. Because many features in the dataset are likely redundant or weakly correlated with class labels, the tree splits may be driven by noise rather than informative patterns. The imbalance problem exacerbates this issue, as the tree learns to minimize classification error by focusing on the largest class. Without pruning or regularization, Decision Trees tend to produce unstable models that perform poorly on such datasets.

# %% [markdown]
# ## 6) Neural Networks

# %%
from keras.utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.regularizers import l2
from keras import Sequential
from keras.layers import Input, Dense
from sklearn.preprocessing import LabelEncoder
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras.callbacks import EarlyStopping
import random 
import tensorflow as tf
from tensorflow.keras.optimizers import Adam

# %%
SEED = 42

X_14 = data_clean_final.iloc[:,0:14]
X = data_clean_final.iloc[:, 0:-1]

encoder = LabelEncoder()
Y_enc = encoder.fit_transform(Y)

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X_14)

# Split into training and test sets (80% train, 20% test)
X_train, X_test, Y_train, Y_test = train_test_split(
    X_scaled, Y_enc, test_size=0.2, shuffle=True, random_state=42, stratify=Y_enc
)

# Further split training set into training and validation
X_train, X_val, Y_train, Y_val = train_test_split(
    X_train, Y_train, test_size=0.2, shuffle=True, random_state=42, stratify=Y_train
)

n_features = X_14.shape[1] 
n_classes = len(np.unique(Y)) 

print(f"\nDataset sizes:")
print(f"Training: {X_train.shape[0]}, Validation: {X_val.shape[0]}, Test: {X_test.shape[0]}")

X_14.head()
# Out:
# Dataset sizes:
# Training: 288, Validation: 73, Test: 91
#    age  height  weight  qrs_duration  p-r_interval  q-t_interval  t_interval  \
# 0   75     190      80            91           193           371         174
# 1   56     165      64            81           174           401         149
# 2   54     172      95           138           163           386         185
# 3   55     175      94           100           202           380         179
# 4   75     190      80            88           181           360         177
#
#    p_interval  qrs     T     P  QRST  heart_rate  r_wave
# 0         121  -16  13.0  64.0  -2.0        63.0      52
# 1          39   25  37.0 -17.0  31.0        53.0      48
# 2         102   96  34.0  70.0  66.0        75.0      40
# 3         143   28  11.0  -5.0  20.0        71.0      72
# 4         103  -16  13.0  61.0   3.0        72.0      48

# %%
# ========================================
# UNDERFIT NEURAL NETWORK
# ========================================

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()

model_small = keras.Sequential([
    layers.Dense(2, activation='relu', input_shape=(n_features,)),
    
    layers.Dense(7, activation='softmax')
])

model_small.compile(
    optimizer=Adam(learning_rate = 0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)


history_small = model_small.fit(x = X_train, y = Y_train, epochs = 200, batch_size = 32, shuffle = True, validation_data = (X_val, Y_val), verbose = 0)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history_small.history['loss'], label='Training Loss')
plt.plot(history_small.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss during training')

plt.subplot(1, 2, 2)
plt.plot(history_small.history['accuracy'], label='Training Accuracy')
plt.plot(history_small.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy during training')

plt.tight_layout()
plt.show()
keras.backend.clear_session()
# Out:
# WARNING:tensorflow:From C:\Users\Inspektor\anaconda3\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
# ========================================
# OPTIMAL FIT NEURAL NETWORK
# ========================================
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()

model_optimal = keras.Sequential([
    layers.Dense(2, activation='relu', input_shape=(n_features,)),
    layers.Dense(3, activation='relu'),
    layers.Dense(7, activation='softmax')
])

model_optimal.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history_optimal = model_optimal.fit(x = X_train, y = Y_train, epochs = 200, 
                                    batch_size = 64, shuffle = True, 
                                    validation_data = (X_val, Y_val), verbose = 0)



plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history_optimal.history['loss'], label='Training Loss')
plt.plot(history_optimal.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss during training')

plt.subplot(1, 2, 2)
plt.plot(history_optimal.history['accuracy'], label='Training Accuracy')
plt.plot(history_optimal.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy during training')

plt.tight_layout()
plt.show()
keras.backend.clear_session()

# %%
# ========================================
# OVERFIT NEURAL NETWORK
# ========================================
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()

model_large = keras.Sequential([
    layers.Dense(8, activation='relu',input_shape=(n_features,)),
    layers.Dense(5, activation='relu'),
    layers.Dense(7, activation='softmax')
])


model_large.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history_large = model_large.fit(x = X_train, y = Y_train, epochs = 200, batch_size = 32, shuffle = True, validation_data = (X_val, Y_val), verbose = 0)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history_large.history['loss'], label='Training Loss')
plt.plot(history_large.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss during training')

plt.subplot(1, 2, 2)
plt.plot(history_large.history['accuracy'], label='Training Accuracy')
plt.plot(history_large.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy during training')

plt.tight_layout()
plt.show()

# %%
# ========================================
# EARLY STOPPING
# ========================================
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()

model_early_stopping = keras.Sequential([
    layers.Dense(8, activation='relu',input_shape=(n_features,)),
    layers.Dense(5, activation='relu'),
    layers.Dense(7, activation='softmax')
])


model_early_stopping.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(monitor = 'val_loss', patience = 5, verbose = 1, mode = 'mini',min_delta=0.02)

history_early_stopping = model_early_stopping.fit(x = X_train, y = Y_train, epochs = 200, batch_size = 32, shuffle = True, validation_data = (X_val, Y_val), callbacks = [early_stop], verbose = 0)

stopped_epoch = len(history_early_stopping.history['loss'])
print(f"\nTraining stopped after {stopped_epoch} epochs (instead of 200)")
print(f"Final Training Loss: {history_early_stopping.history['loss'][-1]:.4f}")
print(f"Final Validation Loss: {history_early_stopping.history['val_loss'][-1]:.4f}")
print(f"Gap Loss: {abs(history_early_stopping.history['loss'][-1] - history_early_stopping.history['val_loss'][-1]):.4f}")
print(f"Final Training Accuracy: {history_early_stopping.history['accuracy'][-1]:.4f}")
print(f"Final Validation Accuracy: {history_early_stopping.history['val_accuracy'][-1]:.4f}")
print(f"Gap Accuracy: {abs(history_early_stopping.history['accuracy'][-1] - history_early_stopping.history['val_accuracy'][-1]):.4f}")

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history_early_stopping.history['loss'], label='Training Loss')
plt.plot(history_early_stopping.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss during training')

plt.subplot(1, 2, 2)
plt.plot(history_early_stopping.history['accuracy'], label='Training Accuracy')
plt.plot(history_early_stopping.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy during training')

plt.tight_layout()
plt.show()
# Out:
# Epoch 34: early stopping
#
# Training stopped after 34 epochs (instead of 200)
# Final Training Loss: 1.3706
# Final Validation Loss: 1.4167
# Gap Loss: 0.0460
# Final Training Accuracy: 0.5486
# Final Validation Accuracy: 0.5616
# Gap Accuracy: 0.0130

# %%
# ========================================
# REGULARIZATION
# ========================================
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)
tf.config.experimental.enable_op_determinism()

model_regularization = keras.Sequential([
    layers.Dense(8, activation='relu',input_shape=(n_features,), kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.1),
    layers.Dense(5, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    layers.Dropout(0.08),
    layers.Dense(7, activation='softmax')
])


model_regularization.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history_regularization  = model_regularization.fit(x = X_train, y = Y_train, epochs = 100, batch_size = 32, shuffle = True, validation_data = (X_val, Y_val), verbose = 0)

print(f"Final Training Loss: {history_regularization.history['loss'][-1]:.4f}")
print(f"Final Validation Loss: {history_regularization.history['val_loss'][-1]:.4f}")
print(f"Gap Loss: {abs(history_regularization.history['loss'][-1] - history_regularization.history['val_loss'][-1]):.4f}")
print(f"Final Training Accuracy: {history_regularization.history['accuracy'][-1]:.4f}")
print(f"Final Validation Accuracy: {history_regularization.history['val_accuracy'][-1]:.4f}")
print(f"Gap Accuracy: {abs(history_regularization.history['accuracy'][-1] - history_regularization.history['val_accuracy'][-1]):.4f}")

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history_regularization.history['loss'], label='Training Loss')
plt.plot(history_regularization.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss during training')

plt.subplot(1, 2, 2)
plt.plot(history_regularization.history['accuracy'], label='Training Accuracy')
plt.plot(history_regularization.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy during training')

plt.tight_layout()
plt.show()
# Out:
# Final Training Loss: 1.2900
# Final Validation Loss: 1.4129
# Gap Loss: 0.1229
# Final Training Accuracy: 0.5903
# Final Validation Accuracy: 0.5479
# Gap Accuracy: 0.0423

# %%
# ==================================================================
# EVALUATION FOR LARGE
# ==================================================================
# Disable retracing spam
import tensorflow as tf
tf.config.run_functions_eagerly(False)

print("\n" + "=" * 70)
print("EVAULATION ON TEST SET")
print("=" * 70)

# Prediction on test set
Y_pred_early = model_large.predict(X_test, verbose=0)
Y_pred_classes = np.argmax(Y_pred_early, axis=1)

# Еvaulation
test_loss, test_accuracy = model_large.evaluate(X_test, Y_test, verbose=0)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f} ({test_accuracy*100:.2f}%)\n")

final_accuracy_large = accuracy_score(Y_test, Y_pred_classes)

print(f"\n{'='*80}")
print("FINAL MODEL PERFORMANCE ON TEST SET")
print(f"{'='*80}")
print(f"Test accuracy: {final_accuracy_large*100:.2f}%")
print(f"Correct predictions: {np.sum(Y_pred_classes == Y_test)}/{len(Y_test)}")

# ========================================
# Confusion Matrix
# ========================================
conf_mat = confusion_matrix(Y_test, Y_pred_classes)
unique_classes = sorted(np.unique(Y_test))

plt.figure(figsize=(10, 8))
sns.heatmap(conf_mat, 
            annot=True, 
            fmt='d', 
            cmap='Greens',
            square=True,
            cbar_kws={'label': 'Number of Samples'},
            xticklabels=unique_classes,
            yticklabels=unique_classes,
            linewidths=0.5,
            linecolor='gray')
plt.title(f'Confusion Matrix - Large neural network \n'
          f'Test Accuracy: {final_accuracy_large:.4f} ({final_accuracy_large*100:.2f}%)', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Predicted Class', fontsize=13, fontweight='bold')
plt.ylabel('True Class', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# ========================================
# Per-class metrics
# ========================================
print(f"\n{'Class':<8} {'Precision':<12} {'Sensitivity':<12} {'Specificity':<12} {'Accuracy':<12}")
print("-" * 80)

precision_list_large = []
sensitivity_list_large = []
specificity_list_large = []
accuracy_list_large = []

for idx, c in enumerate(unique_classes):
    TP = conf_mat[idx, idx]
    FP = conf_mat[:, idx].sum() - TP
    FN = conf_mat[idx, :].sum() - TP
    TN = conf_mat.sum() - (TP + FP + FN)
    
    precision_large = TP / (TP + FP) if (TP + FP) > 0 else 0
    sensitivity_large = TP / (TP + FN) if (TP + FN) > 0 else 0
    specificity_large = TN / (TN + FP) if (TN + FP) > 0 else 0
    accuracy_large = (TP + TN) / (TP + TN + FP + FN) if (TP + TN + FP + FN) > 0 else 0
    
    precision_list_large.append(precision_large)
    sensitivity_list_large.append(sensitivity_large)
    specificity_list_large.append(specificity_large)
    accuracy_list_large.append(accuracy_large)
    
    print(f"{c:<8d} {precision_large:<12.4f} {sensitivity_large:<12.4f} {specificity_large:<12.4f} {accuracy_large:<12.4f}")

# Weighted average
weights_large = [np.sum(Y_test == c) for c in unique_classes]
total = sum(weights_large)
weighted_precision_large = sum(p*w for p,w in zip(precision_list_large, weights_large)) / total
weighted_sensitivity_large = sum(r*w for r,w in zip(sensitivity_list_large, weights_large)) / total
weighted_specificity_large = sum(s*w for s,w in zip(specificity_list_large, weights_large)) / total
weighted_accuracy_large = sum(a*w for a,w in zip(accuracy_list_large, weights_large)) / total


print("-" * 80)
print(f"{'MACRO AVG':<8} {np.mean(precision_list_large):<12.4f} {np.mean(sensitivity_list_large):<12.4f} "
      f"{np.mean(specificity_list_large):<12.4f} {np.mean(accuracy_list_large):<12.4f}")
print(f"{'WEIGHTED':<8} {weighted_precision_large:<12.4f} {weighted_sensitivity_large:<12.4f} "
      f"{weighted_specificity_large:<12.4f} {weighted_accuracy_large:<12.4f}")
print("=" * 80)
# Out:
# ...
# EVAULATION ON TEST SET
# ...
# Test Loss: 1.4871
# Test Accuracy: 0.5934 (59.34%)
#
#
# ...
# FINAL MODEL PERFORMANCE ON TEST SET
# ...
# Test accuracy: 59.34%
# Correct predictions: 54/91
# Class    Precision    Sensitivity  Specificity  Accuracy
# --------------------------------------------------------------------------------
# 0        0.6522       0.9184       0.4286       0.6923
# 1        0.3333       0.1111       0.9756       0.8901
# 2        0.0000       0.0000       0.9773       0.9451
# 3        0.0000       0.0000       1.0000       0.9670
# 4        0.3333       0.2000       0.9767       0.9341
# 5        0.0000       0.0000       1.0000       0.8901
# 6        0.5000       0.5833       0.9114       0.8681
# --------------------------------------------------------------------------------
# MACRO AVG 0.2598       0.2590       0.8957       0.8838
# WEIGHTED 0.4684       0.5934       0.6762       0.7875
# ...

# %%
# ==================================================================
# EVALUATION FOR EARLY STOPPING
# ==================================================================

print("\n" + "=" * 70)
print("EVAULATION ON TEST SET")
print("=" * 70)

# Prediction on test set
Y_pred_early = model_early_stopping.predict(X_test, verbose=0)
Y_pred_classes = np.argmax(Y_pred_early, axis=1)

# Еvaulation
test_loss_es, test_accuracy_es = model_early_stopping.evaluate(X_test, Y_test, verbose=0)
print(f"Test Loss: {test_loss_es:.4f}")
print(f"Test Accuracy: {test_accuracy_es:.4f} ({test_accuracy_es*100:.2f}%)\n")

final_accuracy_es = accuracy_score(Y_test, Y_pred_classes)

print(f"\n{'='*80}")
print("FINAL MODEL PERFORMANCE ON TEST SET")
print(f"{'='*80}")
print(f"Test accuracy: {final_accuracy_es*100:.2f}%")
print(f"Correct predictions: {np.sum(Y_pred_classes == Y_test)}/{len(Y_test)}")

# ========================================
# Confusion Matrix
# ========================================
conf_mat = confusion_matrix(Y_test, Y_pred_classes)
unique_classes = sorted(np.unique(Y_test))

plt.figure(figsize=(10, 8))
sns.heatmap(conf_mat, 
            annot=True, 
            fmt='d', 
            cmap='Greens',
            square=True,
            cbar_kws={'label': 'Number of Samples'},
            xticklabels=unique_classes,
            yticklabels=unique_classes,
            linewidths=0.5,
            linecolor='gray')
plt.title(f'Confusion Matrix - Early stopping\n'
          f'Test Accuracy: {final_accuracy_es:.4f} ({final_accuracy_es*100:.2f}%)', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Predicted Class', fontsize=13, fontweight='bold')
plt.ylabel('True Class', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# ========================================
# Per-class metrics
# ========================================
print(f"\n{'Class':<8} {'Precision':<12} {'Sensitivity':<12} {'Specificity':<12} {'Accuracy':<12}")
print("-" * 80)

precision_list_es = []
sensitivity_list_es = []
specificity_list_es = []
accuracy_list_es = []

for idx, c in enumerate(unique_classes):
    TP = conf_mat[idx, idx]
    FP = conf_mat[:, idx].sum() - TP
    FN = conf_mat[idx, :].sum() - TP
    TN = conf_mat.sum() - (TP + FP + FN)
    
    precision_es = TP / (TP + FP) if (TP + FP) > 0 else 0
    sensitivity_es = TP / (TP + FN) if (TP + FN) > 0 else 0
    specificity_es = TN / (TN + FP) if (TN + FP) > 0 else 0
    accuracy_es = (TP + TN) / (TP + TN + FP + FN) if (TP + TN + FP + FN) > 0 else 0
    
    precision_list_es.append(precision_es)
    sensitivity_list_es.append(sensitivity_es)
    specificity_list_es.append(specificity_es)
    accuracy_list_es.append(accuracy_es)
    
    print(f"{c:<8d} {precision_es:<12.4f} {sensitivity_es:<12.4f} {specificity_es:<12.4f} {accuracy_es:<12.4f}")

# Weighted average
weights_es = [np.sum(Y_test == c) for c in unique_classes]
total = sum(weights_es)
weighted_precision_es = sum(p*w for p,w in zip(precision_list_es, weights_es)) / total
weighted_sensitivity_es = sum(r*w for r,w in zip(sensitivity_list_es, weights_es)) / total
weighted_specificity_es = sum(s*w for s,w in zip(specificity_list_es, weights_es)) / total
weighted_accuracy_es = sum(a*w for a,w in zip(accuracy_list_es, weights_es)) / total 

print("-" * 80)
print(f"{'MACRO AVG':<8} {np.mean(precision_list_es):<12.4f} {np.mean(sensitivity_list_es):<12.4f} "
      f"{np.mean(specificity_list_es):<12.4f} {np.mean(accuracy_list_es):<12.4f}")
print(f"{'WEIGHTED':<8} {weighted_precision_es:<12.4f} {weighted_sensitivity_es:<12.4f} "
      f"{weighted_specificity_es:<12.4f} {weighted_accuracy_es:<12.4f}")
print("=" * 80)
# Out:
# ...
# EVAULATION ON TEST SET
# ...
# Test Loss: 1.5581
# Test Accuracy: 0.5495 (54.95%)
#
#
# ...
# FINAL MODEL PERFORMANCE ON TEST SET
# ...
# Test accuracy: 54.95%
# Correct predictions: 50/91
# Class    Precision    Sensitivity  Specificity  Accuracy
# --------------------------------------------------------------------------------
# 0        0.5444       1.0000       0.0238       0.5495
# 1        0.0000       0.0000       1.0000       0.9011
# 2        0.0000       0.0000       1.0000       0.9670
# 3        0.0000       0.0000       1.0000       0.9670
# 4        0.0000       0.0000       1.0000       0.9451
# 5        0.0000       0.0000       1.0000       0.8901
# 6        1.0000       0.0833       1.0000       0.8791
# --------------------------------------------------------------------------------
# MACRO AVG 0.2206       0.1548       0.8605       0.8713
# WEIGHTED 0.4250       0.5495       0.4744       0.7144
# ...

# %%
# ==================================================================
# EVAULATION FOR REGULARIZATION
# ==================================================================

print("\n" + "=" * 70)
print("EVAULATION ON TEST SET")
print("=" * 70)

# Prediction on test set
Y_pred_early = model_regularization.predict(X_test, verbose=0)
Y_pred_classes = np.argmax(Y_pred_early, axis=1)

# Еvaulation
test_loss_r, test_accuracy_r = model_regularization.evaluate(X_test, Y_test, verbose=0)
print(f"Test Loss: {test_loss_r:.4f}")
print(f"Test Accuracy: {test_accuracy_r:.4f} ({test_accuracy_r*100:.2f}%)\n")

final_accuracy_r = accuracy_score(Y_test, Y_pred_classes)

print(f"\n{'='*80}")
print("FINAL MODEL PERFORMANCE ON TEST SET")
print(f"{'='*80}")
print(f"Test accuracy: {final_accuracy_r*100:.2f}%")
print(f"Correct predictions: {np.sum(Y_pred_classes == Y_test)}/{len(Y_test)}")

# ========================================
# Confusion Matrix
# ========================================
conf_mat = confusion_matrix(Y_test, Y_pred_classes)
unique_classes = sorted(np.unique(Y_test))

plt.figure(figsize=(10, 8))
sns.heatmap(conf_mat, 
            annot=True, 
            fmt='d', 
            cmap='Greens',
            square=True,
            cbar_kws={'label': 'Number of Samples'},
            xticklabels=unique_classes,
            yticklabels=unique_classes,
            linewidths=0.5,
            linecolor='gray')
plt.title(f'Confusion Matrix - Regularization\n'
          f'Test Accuracy: {final_accuracy_r:.4f} ({final_accuracy_r*100:.2f}%)', 
          fontsize=16, fontweight='bold', pad=20)
plt.xlabel('Predicted Class', fontsize=13, fontweight='bold')
plt.ylabel('True Class', fontsize=13, fontweight='bold')
plt.tight_layout()
plt.show()

# ========================================
# Per-class metrics
# ========================================
print(f"\n{'Class':<8} {'Precision':<12} {'Sensitivity':<12} {'Specificity':<12} {'Accuracy':<12}")
print("-" * 80)

precision_list_r = []
sensitivity_list_r = []
specificity_list_r = []
accuracy_list_r = []

for idx, c in enumerate(unique_classes):
    TP = conf_mat[idx, idx]
    FP = conf_mat[:, idx].sum() - TP
    FN = conf_mat[idx, :].sum() - TP
    TN = conf_mat.sum() - (TP + FP + FN)
    
    precision_r = TP / (TP + FP) if (TP + FP) > 0 else 0
    sensitivity_r = TP / (TP + FN) if (TP + FN) > 0 else 0
    specificity_r = TN / (TN + FP) if (TN + FP) > 0 else 0
    class_accuracy_r = (TP + TN) / (TP + TN + FP + FN) if (TP + TN + FP + FN) > 0 else 0
    
    precision_list_r.append(precision_r)
    sensitivity_list_r.append(sensitivity_r)
    specificity_list_r.append(specificity_r)
    accuracy_list_r.append(class_accuracy_r)
    
    print(f"{c:<8d} {precision_r:<12.4f} {sensitivity_r:<12.4f} {specificity_r:<12.4f} {class_accuracy_r:<12.4f}")

# Weighted average
weights_r = [np.sum(Y_test == c) for c in unique_classes]
total = sum(weights_r)
weighted_precision_r = sum(p*w for p,w in zip(precision_list_r, weights_r)) / total
weighted_sensitivity_r = sum(r*w for r,w in zip(sensitivity_list_r, weights_r)) / total
weighted_specificity_r = sum(s*w for s,w in zip(specificity_list_r, weights_r)) / total
weighted_accuracy_r = sum(a*w for a,w in zip(accuracy_list_r, weights_r)) / total


print("-" * 80)
print(f"{'MACRO AVG':<8} {np.mean(precision_list_r):<12.4f} {np.mean(sensitivity_list_r):<12.4f} "
      f"{np.mean(specificity_list_r):<12.4f} {np.mean(accuracy_list_r):<12.4f}")
print(f"{'WEIGHTED':<8} {weighted_precision_r:<12.4f} {weighted_sensitivity_r:<12.4f} "
      f"{weighted_specificity_r:<12.4f} {weighted_accuracy_r:<12.4f}")
print("=" * 80)
# Out:
# ...
# EVAULATION ON TEST SET
# ...
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000023792F1A980> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %% [markdown]
# ## Neural Network
#
# The Neural Network model also resulted in about 57% accuracy, again dominated by predictions of the majority class. This outcome is expected because neural networks require large amounts of data to effectively learn complex nonlinear mappings. In this case, with only ~400 samples and 125 input features, the network has far more trainable parameters than available observations, which leads to severe overfitting and poor generalization. Moreover, without proper class rebalancing or regularization techniques (e.g., dropout, weight decay), the model’s loss function is dominated by the majority class, causing it to ignore minority classes entirely. Thus, the neural network’s low performance and class bias are consistent with the limitations of deep models on small, imbalanced datasets.

# %% [markdown]
# ## 7) Comparative analysis

# %%
# ============================================================================
# COMPARISON TABLE FOR ALL CLASSIFICATION METHODS
# ============================================================================

# Prepare data for comparison table
comparison_data = {
    'Method': [
        'Hypothesis Testing (Bayes)',
        'KNN',
        'Decision tree',
        'Neural Network large',
        'Neural Network early stopping',
        'Neural Network regularization'
    ],
    'Precision': [
        np.mean(precision_list_ht), 
        np.mean(precision_list_knn), 
        np.mean(precision_list_dt), 
        np.mean(precision_list_large), 
        np.mean(precision_list_es), 
        np.mean(precision_list_r) 
    ],
    'Recall (Sensitivity)': [
        np.mean(sensitivity_list_ht), 
        np.mean(sensitivity_list_knn), 
        np.mean(sensitivity_list_dt), 
        np.mean(sensitivity_list_large), 
        np.mean(sensitivity_list_es), 
        np.mean(sensitivity_list_r) 
    ],
    'Specificity': [
        np.mean(specificity_list_ht), 
        np.mean(specificity_list_knn), 
        np.mean(specificity_list_dt), 
        np.mean(specificity_list_large), 
        np.mean(specificity_list_es), 
        np.mean(specificity_list_r)
    ],
    'Classification Accuracy': [
        np.mean(accuracy_list_ht), 
        np.mean(accuracy_list_knn), 
        np.mean(accuracy_list_dt), 
        np.mean(accuracy_list_large), 
        np.mean(accuracy_list_es), 
        np.mean(accuracy_list_r)
    ],
    'Overall Accuracy': [
        accuracy_ht_overall, 
        final_accuracy_knn, 
        final_accuracy_dt, 
        final_accuracy_large, 
        final_accuracy_es, 
        final_accuracy_r
    ]
}

# Create DataFrame
df_comparison = pd.DataFrame(comparison_data)

# Display table
print("\n" + "="*140)
print("COMPARISON OF CLASSIFICATION METHODS".center(100))
print("="*140)
print(df_comparison.to_string(index=False))
print("="*140)

# Find best method for each metric
print("\nBEST PERFORMING METHOD FOR EACH METRIC:")
print("-"*140)
for metric in ['Precision', 'Recall (Sensitivity)', 'Specificity', 'Classification Accuracy', 'Overall Accuracy']:
    best_idx = df_comparison[metric].idxmax()
    best_method = df_comparison.loc[best_idx, 'Method']
    best_value = df_comparison.loc[best_idx, metric]
    print(f"  {metric:<25}: {best_method:<30} ({best_value:.4f})")
print("="*140)

# Visualise analitics
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 6))

x = np.arange(len(df_comparison['Method']))
width = 0.15  

metrics = ['Precision', 'Recall (Sensitivity)', 'Specificity', 'Classification Accuracy', 'Overall Accuracy']
colors = ['#2ecc71', '#3498db', '#e74c3c', '#f39c12', '#9b59b6']


for i, metric in enumerate(metrics):
    ax.bar(x + (i - len(metrics)/2 + 0.5) * width, df_comparison[metric], width, label=metric, color=colors[i])

ax.set_xlabel('Classification Method', fontsize=12, fontweight='bold')
ax.set_ylabel('Score', fontsize=12, fontweight='bold')
ax.set_title('Comparison of Classification Methods - All Metrics', fontsize=14, fontweight='bold')


ax.set_xticks(x)
ax.set_xticklabels(df_comparison['Method'], rotation=15, ha='right')

ax.legend()
ax.grid(axis='y', alpha=0.3)
ax.set_ylim([0, 1])

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 17
#       1 # ============================================================================
#       2 # COMPARISON TABLE FOR ALL CLASSIFICATION METHODS
#       3 # ============================================================================
#       4
#       5 # Prepare data for comparison table
#       6 comparison_data = {
#       7     'Method': [
#       8         'Hypothesis Testing (Bayes)',
#       9         'KNN',
#      10         'Decision tree',
#      11         'Neural Network large',
#      12         'Neural Network early stopping',
#      13         'Neural Network regularization'
#      14     ],
#      15     'Precision': [
#      16         np.mean(precision_list_ht),
# ---> 17         np.mean(precision_list_knn),
#      18         np.mean(precision_list_dt),
# ...

# %% [markdown]
# #### Several classification approaches were evaluated, including Linear Discriminant Analysis (LDA) and Multiple Hypothesis Test, k-Nearest Neighbors (kNN), Decision Tree, and a Neural Network classifier.

# %% [markdown]
# ## Performance Overview:
#
# -The LDA + Multiple Hypothesis Test based approach achieved the best performance, reaching an accuracy of approximately 82% when combined with a multiple hypothesis testing framework for classification. In contrast, the nonparametric methods (kNN, Decision Tree, and Neural Network) achieved significantly lower accuracies, around 55%, and tended to assign nearly all samples to the dominant class (class 1), thus producing misleadingly high accuracy values due to the class imbalance.

# %% [markdown]
# ## Interpretation:
#
# -This outcome is consistent with theoretical expectations.
# Given the high dimensionality (125 features) and relatively small number of samples (400), nonparametric methods such as kNN, Decision Trees, and Neural Networks are prone to overfitting and poor generalization. These methods attempt to learn complex decision boundaries, which is difficult and unstable when the data are sparse in a high-dimensional feature space.
#
# In contrast, LDA + Multiple Hypothesis Test performs both dimensionality reduction and supervised linear transformation, projecting the data into a subspace that maximizes class separability while minimizing within-class variance. This property makes LDA + Multiple Hypothesis Test particularly robust in small-sample, high-dimensional settings. Moreover, LDA effectively mitigates overfitting by imposing strong linear assumptions and relying on global covariance estimation.
#
# The high performance of the LDA + Multiple Hypothesis Test-based method therefore indicates that the classes in the dataset are linearly (or near-linearly) separable when projected into a suitable discriminant space, while more flexible models fail to generalize due to data scarcity and imbalance.

# %% [markdown]
# ## Conclusion
#
# -Overall, the experimental results demonstrate that parametric, regularized methods such as LDA are more suitable for this dataset than nonparametric approaches.
# The imbalanced class distribution severely affects models that rely on local decision boundaries or require large sample sizes, such as kNN, Decision Trees, and Neural Networks.
